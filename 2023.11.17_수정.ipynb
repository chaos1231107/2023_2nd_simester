# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
def f(x):
    x1, x2 = x[:,0:1], x[:,1:]
    y1 = x1 + x2
    y2 = x1 * x2
    return np.concatenate((y1,y2),axis=-1)

x_train = np.random.uniform(-2,2,size=(100,2))
y_train = f(x_train)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(2,)),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(2)
])

model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_12 (Dense)            (None, 10)                30
#
#  dense_13 (Dense)            (None, 10)                110
#
#  dense_14 (Dense)            (None, 2)                 22
#
# ...
# Total params: 162 (648.00 Byte)
# Trainable params: 162 (648.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
x_test = np.random.uniform(-2,2,size=(20,2))
y_test = f(x_test)

# %%
model.fit(x_train, y_train,epochs=1000, validation_data=(x_test, y_test))
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0024
# Epoch 2/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0024
# Epoch 3/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0025
# Epoch 4/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0025
# Epoch 5/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0025
# Epoch 6/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0025
# Epoch 7/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0025
# Epoch 8/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0027
# Epoch 9/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 10/1000
# ...

# %%
y_pred = model.predict(x_test)
plt.plot(y_pred[:,0], y_pred[:,1], 'ko', label='predict')
plt.plot(y_test[:,0], y_test[:,1], '*r', label='actual')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 13ms/step

# %%
def NN(x):
    x1,x2,x3,x4 = x[:,0:1], x[:,1:2], x[:,2:3], x[:,3:]
    y1 = tf.math.cos(x1 + x2 + x3 + x4)
    y2 = tf.math.sin(x1 + x2)
    y3 = tf.math.cos(x1 + x2) + tf.math.sin(x3 + x4)
    return np.concatenate((y1,y2,y3), axis=-1)

x_train = np.random.uniform(-2,2,size=(1000,4))
y_train = NN(x_train)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(4,)),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(3)
])

model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_33 (Dense)            (None, 100)               500
#
#  dense_34 (Dense)            (None, 100)               10100
#
#  dense_35 (Dense)            (None, 3)                 303
#
# ...
# Total params: 10903 (42.59 KB)
# Trainable params: 10903 (42.59 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
x_test = np.random.uniform(-2,2,size=(100,4))
y_test = NN(x_test)

# %%
model.fit(x_train, y_train, epochs=1000, validation_data=(x_test, y_test))
# Out:
# Epoch 1/1000
# 32/32 [==============================] - 0s 1ms/step - loss: 1.9970e-04 - val_loss: 8.4065e-04
# Epoch 2/1000
# 32/32 [==============================] - 0s 787us/step - loss: 3.0241e-04 - val_loss: 5.2462e-04
# Epoch 3/1000
# 32/32 [==============================] - 0s 796us/step - loss: 2.8070e-04 - val_loss: 6.0656e-04
# Epoch 4/1000
# 32/32 [==============================] - 0s 764us/step - loss: 1.7389e-04 - val_loss: 4.0340e-04
# Epoch 5/1000
# 32/32 [==============================] - 0s 820us/step - loss: 1.7315e-04 - val_loss: 4.3777e-04
# Epoch 6/1000
# 32/32 [==============================] - 0s 797us/step - loss: 1.6221e-04 - val_loss: 4.8639e-04
# Epoch 7/1000
# 32/32 [==============================] - 0s 768us/step - loss: 1.6983e-04 - val_loss: 4.3290e-04
# Epoch 8/1000
# 32/32 [==============================] - 0s 844us/step - loss: 1.2105e-04 - val_loss: 3.3785e-04
# Epoch 9/1000
# ...

# %%
y_pred = model.predict(x_test)
y_pred.shape
# Out:
# 4/4 [==============================] - 0s 797us/step
# (100, 3)

# %%
plt.plot(y_pred[:,0], y_pred[:,1], y_pred[:,2], 'ko',label='predict')
plt.plot(y_test[:,0], y_test[:,1], y_test[:,2], '*r',label='actual')
plt.legend()
plt.show()
